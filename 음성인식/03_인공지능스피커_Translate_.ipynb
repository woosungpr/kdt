# %%
# !pip install click==8.1.8
# Out:
# Requirement already satisfied: click==8.1.8 in /usr/local/lib/python3.12/dist-packages (8.1.8)

# %%
# !pip install gTTS
# Out:
# Requirement already satisfied: gTTS in /usr/local/lib/python3.12/dist-packages (2.5.4)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.12/dist-packages (from gTTS) (2.32.4)
# Requirement already satisfied: click<8.2,>=7.1 in /usr/local/lib/python3.12/dist-packages (from gTTS) (8.1.8)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->gTTS) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->gTTS) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->gTTS) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->gTTS) (2026.2.25)

# %%
# !pip install translate
# Out:
# Requirement already satisfied: translate in /usr/local/lib/python3.12/dist-packages (3.8.0)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from translate) (8.1.8)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (from translate) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from translate) (2.32.4)
# Requirement already satisfied: libretranslatepy==2.1.1 in /usr/local/lib/python3.12/dist-packages (from translate) (2.1.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->translate) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->translate) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->translate) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->translate) (2026.2.25)

# %% [markdown]
# - translate 패키지는 내부적으로 무료 번역 엔진 중 하나를 사용하여 번역을 수행함
#   - Google Translate API
#   - Microsoft Bing Translator API
#   - Yandex Translator API

# %% [markdown]
# 2) TEXT 번역하기

# %%
from translate import Translator

text = '안녕하세요. 제 이름은 인공지능 스피커입니다.'

# translator 객체 생성
translator= Translator(to_lang="ja", from_lang='ko')
# translation = translator.translate("Hello World!")
# print(translation)

# %%
# 번역 실행
result = translator.translate(text) # 한국어를 영어로 번역

print('원본 텍스트 :', text)
print('번역된 텍스트:',result)
# Out:
# 원본 텍스트 : 안녕하세요. 제 이름은 인공지능 스피커입니다.
# 번역된 텍스트: こんにちは、AIスピーカーと申します。

# %%
from gtts import gTTS
#  텍스트 문장 사운드 파일 생성 및 저장
file_name = 'japanese1.mp3'
tts_en = gTTS(text=result, lang='ja')
tts_en.save(file_name)

# %%
#  코랩 환경에서 .mp3 파일 재생
from IPython.display import Audio
sound = Audio(file_name, autoplay=True)
sound
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
